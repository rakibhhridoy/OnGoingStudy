# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pca3.csv")

# %%
df.head()
# Out:
#   Element   PC1   PC2   PC3
# 0      Cr  0.94  0.03  0.20
# 1      Mn  0.08  0.66  0.71
# 2      Fe   0.4  0.68  0.60
# 3      Co  0.88 -0.36  0.02
# 4      Cu  0.29  0.65 -0.37

# %%
df.columns
# Out:
# Index(['Element', 'PC1', 'PC2', 'PC3'], dtype='object')

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"])
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"], s=100)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"],s=100, c= "black")

ax.set_xlabel("PC1")
plt.colorbar(fg)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(df["PC1"], df["PC2"], df["PC3"],s=100, c= "black", alpha= 0.9)

ax.set_label("df.Element")
ax.set_xlabel("PC1")
plt.colorbar(fg)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
pca = pd.read_csv("pca_scores.csv")

# %%
pca
# Out:
#    Unnamed: 0      Comp.1     Comp.2     Comp.3    Comp.4    Comp.5    Comp.6  \
# 0          Cr  -55.435664  -1.548130  -1.845450 -1.129890 -0.127578 -0.292413
# 1          Mn  -55.946901  -1.428017  -2.620968 -0.132888  1.446824  0.313311
# 2          Fe  206.414568  57.849049  -2.041158  0.047060  0.087767  0.000556
# 3          Co  -49.235845  -2.155227  -1.683549 -1.474310 -2.065640  0.879373
# 4          Cu   -2.984061   3.337488  13.690817 -2.647765  1.533267  0.057006
# 5          Zn  328.925673 -39.588002  -1.131932 -0.343371  0.142993 -0.003833
# 6          As  -57.422805  -2.508123  -2.077538 -0.219761  0.769137 -0.063682
# 7          Se  -47.014448  -1.758181  -1.109903 -0.853153 -1.351170 -0.327142
# 8          Pb  -56.804396  -2.330780  -1.901333  0.014514  0.706810  0.014377
# 9          Cd  -53.841708  -1.578058  -2.281204 -1.551340 -0.840595 -0.331045
# 10         Hg  -55.832036  -2.496036  -1.805911 -0.928835  0.795171 -0.135589
# ...

# %%
pca.rename(columns = {'Unnamed: 0':'Elements'}, inplace = True)

# %%
pca
# Out:
#    Elements      Comp.1     Comp.2     Comp.3    Comp.4    Comp.5    Comp.6  \
# 0        Cr  -55.435664  -1.548130  -1.845450 -1.129890 -0.127578 -0.292413
# 1        Mn  -55.946901  -1.428017  -2.620968 -0.132888  1.446824  0.313311
# 2        Fe  206.414568  57.849049  -2.041158  0.047060  0.087767  0.000556
# 3        Co  -49.235845  -2.155227  -1.683549 -1.474310 -2.065640  0.879373
# 4        Cu   -2.984061   3.337488  13.690817 -2.647765  1.533267  0.057006
# 5        Zn  328.925673 -39.588002  -1.131932 -0.343371  0.142993 -0.003833
# 6        As  -57.422805  -2.508123  -2.077538 -0.219761  0.769137 -0.063682
# 7        Se  -47.014448  -1.758181  -1.109903 -0.853153 -1.351170 -0.327142
# 8        Pb  -56.804396  -2.330780  -1.901333  0.014514  0.706810  0.014377
# 9        Cd  -53.841708  -1.578058  -2.281204 -1.551340 -0.840595 -0.331045
# 10       Hg  -55.832036  -2.496036  -1.805911 -0.928835  0.795171 -0.135589
# ...

# %%
# %matplotlib notebook

plt.figure(figsize=(10,8))

ax = plt.axes(projection="3d")
fg = ax.scatter3D(pca["Comp.1"],pca["Comp.2"],pca["Comp.3"], s= 70, c= "black")
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
arrayx = np.array([pca["Comp.1"]])
arrayy = np.array([pca["Comp.2"]])
arrayz = np.array([pca["Comp.3"]])

# %%
labels = list(pca["Elements"])
labels
# Out:
# ['Cr',
#  'Mn',
#  'Fe',
#  'Co',
#  'Cu',
#  'Zn',
#  'As',
#  'Se',
#  'Pb',
#  'Cd',
#  'Hg',
#  'Protein',
#  'O3PFA',
#  'Lipid']

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

ax3d = plt.figure().gca(projection='3d')

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

ax3d.scatter(arrayx, arrayy, arrayz, c="black")

#give the labels to each point
for x_label, y_label, z_label, label in zip(arrayx, arrayy, arrayz, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
plt.savefig("pca_3d.png", format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /tmp/ipykernel_7468/1088736004.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
arrayx
# Out:
# array([-55.43566367, -55.94690129, 206.41456777, -49.23584526,
#         -2.98406062, 328.92567261, -57.42280503, -47.01444792,
#        -56.80439576, -53.84170811, -55.83203577, -12.82624146,
#        -57.92363987, -30.07249561])

# %%
from sklearn import preprocessing

# %%
x = preprocessing.normalize([arrayx])
x
# Out:
# array([[-0.13117058, -0.13238025,  0.48841334, -0.11650071, -0.00706081,
#          0.77829626, -0.1358725 , -0.11124449, -0.13440924, -0.127399  ,
#         -0.13210846, -0.03034915, -0.13705757, -0.07115684]])

# %%
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])
y,z
# Out:
# array([[-0.0219562 , -0.02025271,  0.82043823, -0.03056628,  0.04733358,
#         -0.5614528 , -0.0355712 , -0.02493522, -0.03305605, -0.02238064,
#         -0.03539978, -0.00750859, -0.03573654, -0.0389558 ]])

# %%
ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x, y, z, c="black")

#give the labels to each point
for x_label, y_label, z_label, label in zip(x, y, z, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /tmp/ipykernel_7468/3727692418.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
arrayx.shape
# Out:
# (14,)

# %%
labels
# Out:
# ['Cr',
#  'Mn',
#  'Fe',
#  'Co',
#  'Cu',
#  'Zn',
#  'As',
#  'Se',
#  'Pb',
#  'Cd',
#  'Hg',
#  'Protein',
#  'O3PFA',
#  'Lipid']

# %%
x.shape
# Out:
# (1, 14)

# %%
x
# Out:
# array([[-0.13117058, -0.13238025,  0.48841334, -0.11650071, -0.00706081,
#          0.77829626, -0.1358725 , -0.11124449, -0.13440924, -0.127399  ,
#         -0.13210846, -0.03034915, -0.13705757, -0.07115684]])

# %%
x_reshape = x.reshape(14,)

# %%
x_reshape.shape
# Out:
# (14,)

# %%
y_reshape = y.reshape(14,)
z_reshape = z.reshape(14,)

# %%
ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

#give the labels to each point
for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /tmp/ipykernel_7468/44562996.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

pca = pd.read_csv("pca_scores.csv")
pca.rename(columns = {'Unnamed: 0':'Elements'}, inplace = True)

arrayx = np.array([pca["Comp.1"]])
arrayy = np.array([pca["Comp.2"]])
arrayz = np.array([pca["Comp.3"]])

arrayx = arrayx.flatten()
arrayy = arrayy.flatten()
arrayz = arrayz.flatten()

labels = list(pca["Elements"])
x = preprocessing.normalize([arrayx])
y = preprocessing.normalize([arrayy])
z = preprocessing.normalize([arrayz])

x_reshape = x.reshape(14,)
y_reshape = y.reshape(14,)
z_reshape = z.reshape(14,)

ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
plt.savefig("pca_3d.png", format="png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /tmp/ipykernel_7468/2322253493.py:26: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')

# %%
labels
# Out:
# ['Cr',
#  'Mn',
#  'Fe',
#  'Co',
#  'Cu',
#  'Zn',
#  'As',
#  'Se',
#  'Pb',
#  'Cd',
#  'Hg',
#  'Protein',
#  'O3PFA',
#  'Lipid']

# %%
n_labels = ['Cr',
 'Mn',
 'Fe',
 'Co',
 'Cu',
 'Zn',
 'As',
 'Se',
 'Pb',
 'Cd',
 'Hg',
 'Pr',
 'Om',
 'Lip']

# %%
ax3d = plt.figure().gca(projection='3d')

ax3d.scatter(x_reshape, y_reshape, z_reshape, c="black")

for x_label, y_label, z_label, label in zip(x_reshape, y_reshape, z_reshape, n_labels):
    ax3d.text(x_label, y_label, z_label, label)

ax3d.set_xlabel("PC1 (50.63%)")
ax3d.set_ylabel("PC2 (17.25%)")
ax3d.set_zlabel("PC3 (13.08%)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /tmp/ipykernel_7468/1425716219.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax3d = plt.figure().gca(projection='3d')
