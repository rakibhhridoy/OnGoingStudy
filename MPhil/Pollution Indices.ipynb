# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv("data/data.csv")
bg = pd.read_csv("data/bg.csv")

# %%
df
# Out:
#    Sampling sites    CdW    CdR  SrW  SrR     FeW    FeR    HgW   HgR   CoW  \
# 0          Site 1   9.78   6.70  248  205   66870  42870   7.29  4.25  7.13
# 1          Site 2   9.17   6.10  230  172   51450  59450   7.29  4.24  6.98
# 2          Site 3   9.89   6.75  254  232   62650  67650   7.47  4.34  7.20
# 3          Site 4   9.45   6.27  277  202   50560  63580   7.45  4.34  7.17
# 4          Site 5   8.60   5.47  193  165   47800  54450   7.28  4.24  6.97
# 5          Site 6   9.30   6.21  197  180   68970  75170   7.41  4.27  7.10
# 6          Site 7  10.98   7.40  341  331   99700  48700   7.59  4.35  7.34
# 7          Site 8  12.12   7.90  398  352   41455  47455   7.63  4.38  7.36
# 8          Site 9  14.19   7.72  417  379  136470  42590  12.02  4.53  7.95
# 9         Site 10  16.53   9.98  423  392  169780  38780  17.26  5.17  9.79
# 10        Site 11  14.78  10.12  404  393  107800  64100  10.08  4.61  8.14
# 11        Site 12   9.14   6.07  219  170   45780  52990   7.39  4.27  6.95
# 12        Site 13  10.45   6.90  277  233   53478  61478   7.55  4.43  7.31
# 13        Site 14  14.83  10.55  363  299  139785  46185   9.23  4.71  8.23
# 14        Site 15  14.92  10.62  410  372  134900  38900   8.25  4.72  8.55
# 15        Site 16  15.89  11.75  400  384  150680  64680  18.31  4.88  7.69
# 16        Site 17  14.10  12.33  415  386   39780  38780   7.85  4.48  7.65
# 17        Site 18  11.16   7.42  289  238   61460  66460   7.89  4.53  7.43
# 18        Site 19  12.18   7.75  406  383   60980  67100   8.10  4.61  8.19
# 19        Site 20  14.05   9.97  402  365  143480  49480  15.81  4.42  7.37
#
#     ...      CuW     CuR     MnW     MnR    CrW    CrR    PbW    PbR     AsW  \
# 0   ...   802.40  322.10  1811.7   797.8  298.2   54.2  256.8  169.7   72.60
# 1   ...   793.40  313.90  2202.1  1000.4  300.4   56.3  359.7  177.1   84.70
# 2   ...   798.70  319.70  2263.7  1152.1  376.6  132.6  828.6  231.6  217.90
# 3   ...   796.40  315.40  2116.4  1029.8  361.8  117.3  787.3  188.3  213.30
# 4   ...   792.44  311.44  2013.5   919.8  353.7  109.7  767.2  170.3  212.50
# 5   ...   805.90  355.90  2270.5  1181.4  448.3  204.8  846.3  249.3  228.70
# 6   ...   945.70  505.70  1859.8   836.9  380.4  134.4  813.7  226.7  214.20
# 7   ...   845.90  345.90  1919.8   812.4  378.8  144.8  807.4  220.4  214.50
# 8   ...   848.70  368.40  2310.3   790.5  328.8   84.2  763.1  166.3  210.90
# 9   ...   906.40  426.80  3808.7   755.1  319.5   75.5  759.3  162.3  209.25
# 10  ...   993.40  505.30  2041.4  1032.5  518.4  274.3  855.9  258.7  237.80
# 11  ...   791.70  320.20  1937.9   910.9  356.8  112.8  769.4  172.3  212.30
# 12  ...   842.40  362.70  2210.6  1016.9  444.4  200.4  836.9  239.2  228.20
# 13  ...   998.70  518.30  2423.4   808.3  560.4  236.4  889.3  312.3  241.90
# 14  ...  1032.10  442.10  2301.7   775.3  456.1  134.1  860.8  263.8  231.80
# 15  ...   845.70  365.70  3554.8  1106.3  452.2  128.7  857.5  280.5  230.10
# 16  ...   847.30  357.30  1818.6   756.1  576.5  252.5  875.2  298.2  244.90
# 17  ...   839.40  325.40  2251.3  1130.6  331.7  122.7  768.7  191.7  212.30
# 18  ...   880.30  340.30  2249.8  1148.7  316.9   72.5  747.1  170.1  206.40
# 19  ...   822.40  348.40  3296.4   901.7  299.3   55.3  757.7  180.7  202.80
#
#      AsR
# 0   56.9
# 1   59.2
# 2   72.1
# 3   67.3
# 4   67.2
# 5   81.8
# 6   68.3
# 7   69.0
# 8   65.3
# 9   64.3
# 10  91.4
# 11  59.3
# 12  80.4
# 13  94.7
# 14  86.1
# 15  80.7
# 16  89.2
# 17  68.6
# 18  63.4
# 19  58.2
#
# [20 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sampling sites  20 non-null     object
#  1   CdW             20 non-null     float64
#  2   CdR             20 non-null     float64
#  3   SrW             20 non-null     int64
#  4   SrR             20 non-null     int64
#  5   FeW             20 non-null     int64
#  6   FeR             20 non-null     int64
#  7   HgW             20 non-null     float64
#  8   HgR             20 non-null     float64
#  9   CoW             20 non-null     float64
#  10  CoR             20 non-null     float64
#  11  NiW             20 non-null     float64
#  12  NiR             20 non-null     float64
#  13  CuW             20 non-null     float64
#  14  CuR             20 non-null     float64
#  15  MnW             20 non-null     float64
#  16  MnR             20 non-null     float64
#  17  CrW             20 non-null     float64
#  18  CrR             20 non-null     float64
#  19  PbW             20 non-null     float64
#  20  PbR             20 non-null     float64
#  21  AsW             20 non-null     float64
#  22  AsR             20 non-null     float64
# dtypes: float64(18), int64(4), object(1)
# memory usage: 3.7+ KB

# %% [markdown]
# ```
# Metals:
#     Cd, Sr, Fe, Hg, Co, Ni, Cu, Mn, Cr, Pb, As
# ```

# %%
bg.T.values
# Out:
# array([[1.200e+00],
#        [1.660e+02],
#        [2.179e+04],
#        [1.700e-01],
#        [1.700e-01],
#        [1.573e+01],
#        [3.400e+01],
#        [4.310e+02],
#        [1.615e+01],
#        [1.300e+01],
#        [6.910e+00]])

# %%
bg
# Out:
#     Cd   Sr     Fe    Hg    Co     Ni  Cu   Mn     Cr  Pb    As
# 0  1.2  166  21790  0.17  0.17  15.73  34  431  16.15  13  6.91

# %%
bg["Cd"][0]
# Out:
# 1.2

# %% [markdown]
# # Igeo

# %%
igeo_CdW = []
igeo_CdR = []

igeo_SrW = []
igeo_SrR = []

igeo_FeW = []
igeo_FeR = []

igeo_HgW = []
igeo_HgR = []

igeo_CoW = []
igeo_CoR = []

igeo_NiW = []
igeo_NiR = []

igeo_CuW = []
igeo_CuR = []

igeo_MnW = []
igeo_MnR = []

igeo_CrW = []
igeo_CrR = []

igeo_PbW = []
igeo_PbR = []

igeo_AsW = []
igeo_AsR = []


i = 0
while i < len(df["PbR"]):
    ig_Cdr = math.log2(df["CdR"][i]/ (1.5 * bg["Cd"][0]))
    igeo_CdR.append(ig_Cdr)
    
    ig_Cdw = math.log2(df["CdW"][i]/ (1.5 * bg["Cd"]))
    igeo_CdW.append(ig_Cdw)
    
    
    ig_Srw = math.log2(df["SrW"][i]/ (1.5 * bg["Sr"][0]))
    igeo_SrW.append(ig_Srw)
    
    ig_Srr = math.log2(df["SrR"][i]/ (1.5 * bg["Sr"][0]))
    igeo_SrR.append(ig_Srr)
    
    
    ig_Few = math.log2(df["FeW"][i]/ (1.5 * bg["Fe"][0]))
    igeo_FeW.append(ig_Few)
    
    ig_Fer = math.log2(df["FeR"][i]/ (1.5 * bg["Fe"][0]))
    igeo_FeR.append(ig_Fer)
    
    
    ig_Hgr = math.log2(df["HgR"][i]/ (1.5 * bg["Hg"][0]))
    igeo_HgR.append(ig_Hgr)
    
    ig_Hgw = math.log2(df["HgW"][i]/ (1.5 * bg["Hg"][0]))
    igeo_HgW.append(ig_Hgw)
    
    
    ig_Cor = math.log2(df["CoR"][i]/ (1.5 * bg["Co"][0]))
    igeo_CoR.append(ig_Cor)
    
    ig_Cow = math.log2(df["CoW"][i]/ (1.5 * bg["Co"][0]))
    igeo_CoW.append(ig_Cow)
    
    
    ig_Nir = math.log2(df["NiR"][i]/ (1.5 * bg["Ni"][0]))
    igeo_NiR.append(ig_Nir)
    
    ig_Niw = math.log2(df["NiW"][i]/ (1.5 * bg["Ni"][0]))
    igeo_NiW.append(ig_Niw)
    
    
    ig_Mnr = math.log2(df["MnR"][i]/ (1.5 * bg["Mn"][0]))
    igeo_MnR.append(ig_Mnr)
    
    ig_Mnw = math.log2(df["MnW"][i]/ (1.5 * bg["Mn"][0]))
    igeo_MnW.append(ig_Mnw)
    
    
    ig_Cur = math.log2(df["CuR"][i]/ (1.5 * bg["Cu"][0]))
    igeo_CuR.append(ig_Cur)
    
    ig_Cuw = math.log2(df["CuW"][i]/ (1.5 * bg["Cu"][0]))
    igeo_CuW.append(ig_Cuw)
    
    
    ig_Crr = math.log2(df["CrR"][i]/ (1.5 * bg["Cr"][0]))
    igeo_CrR.append(ig_Crr)    
    
    ig_Crw = math.log2(df["CrW"][i]/ (1.5 * bg["Cr"][0]))
    igeo_CrW.append(ig_Crw)    
    
    
    ig_pbr = math.log2(df["PbR"][i]/ (1.5 * bg["Pb"][0]))
    igeo_PbR.append(ig_pbr)
    
    ig_pbw = math.log2(df["PbW"][i]/ (1.5 * bg["Pb"][0]))
    igeo_PbW.append(ig_pbw)
    
    
    ig_Asr = math.log2(df["AsR"][i]/ (1.5 * bg["As"][0]))
    igeo_AsR.append(ig_Asr)
    
    ig_Asw = math.log2(df["AsW"][i]/ (1.5 * bg["As"][0]))
    igeo_AsW.append(ig_Asw)
    
    
    
    
    i += 1
    
    
    
    
igeo = pd.DataFrame({
    "CdW": igeo_CdW,
    "CdR": igeo_CdR,
    "SrW": igeo_SrW,
    "SrR": igeo_SrR,
    "FeW": igeo_FeW,
    "FeR": igeo_FeR,
    "HgW": igeo_HgW,
    "HgR": igeo_HgR,
    "CoW": igeo_CoW,
    "CoR": igeo_CoR,
    "NiW": igeo_NiW,
    "NiR": igeo_NiR,
    "MnW": igeo_MnW,
    "MnR": igeo_MnR,
    "CuW": igeo_CuW,
    "CuR": igeo_CuR,
    "CrW": igeo_CrW,
    "CrR": igeo_CrR,
    "PbW": igeo_PbW,
    "PbR": igeo_PbR,
    "AsW": igeo_AsW,
    "AsR": igeo_AsR
    
})

igeoW = igeo[["CdW", "SrW","FeW","HgW","CoW","NiW","MnW", "CuW","CrW","PbW","AsW"]]
igeoR = igeo[["CdR", "SrR","FeR","HgR","CoR","NiR","MnR", "CuR","CrR","PbR","AsR"]]

# %%
igeo
# Out:
#          CdW       CdR       SrW       SrR       FeW       FeR       HgW  \
# 0   2.441838  1.896164 -0.005806 -0.280522  1.032730  0.391340  4.837350
# 1   2.348925  1.760812 -0.114512 -0.533737  0.654542  0.863048  4.837350
# 2   2.457974  1.906891  0.028683 -0.102021  0.938686  1.049461  4.872539
# 3   2.392317  1.800469  0.153740 -0.301790  0.629368  0.959944  4.868671
# 4   2.256340  1.603544 -0.367545 -0.593680  0.548382  0.736303  4.835369
# 5   2.369234  1.786596 -0.337950 -0.468149  1.077340  1.201528  4.860904
# 6   2.608809  2.039528  0.453626  0.410685  1.608965  0.575293  4.895531
# 7   2.751321  2.133856  0.676623  0.499430  0.342917  0.537931  4.903114
# 8   2.978806  2.100604  0.743902  0.606052  2.061883  0.381886  5.558796
# 9   3.199018  2.471043  0.764512  0.654708  2.376966  0.246684  6.080791
# 10  3.037577  2.491140  0.698210  0.658384  1.721657  0.971696  5.304855
# 11  2.344197  1.753700 -0.185215 -0.550611  0.486089  0.697091  4.857005
# 12  2.537434  1.938599  0.153740 -0.095816  0.710317  0.911442  4.887907
# 13  3.042450  2.551174  0.543824  0.264000  2.096509  0.498796  5.177761
# 14  3.051179  2.560715  0.719478  0.579157  2.045190  0.251141  5.015825
# 15  3.142050  2.706592  0.683854  0.624961  2.204787  0.984691  6.165991
# 16  2.969626  2.776104  0.736966  0.632455  0.283415  0.246684  4.944124
# 17  2.632268  2.043422  0.214924 -0.065184  0.911019  1.023858  4.951456
# 18  2.758445  2.106199  0.705334  0.621199  0.899707  1.037684  4.989353
# 19  2.964501  2.469597  0.691050  0.551751  2.134149  0.598217  5.954196
#
#          HgR       CoW       CoR  ...       MnW       MnR       CuW       CuR  \
# 0   4.058894  4.805333  3.626783  ...  1.486622  0.303377  3.975752  2.658940
# 1   4.055495  4.774658  3.580240  ...  1.768158  0.629855  3.959479  2.621736
# 2   4.089126  4.819428  3.404390  ...  1.807961  0.833544  3.969085  2.648150
# 3   4.089126  4.813404  3.693897  ...  1.710890  0.671642  3.964924  2.628614
